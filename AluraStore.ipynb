# %% [markdown]
# <a href="https://colab.research.google.com/github/andrecastrogarciams/alurastore/blob/main/AluraStore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja1 = pd.read_csv(url1)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja1.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# 1    cartao_credito                       4 -22.25 -42.66
# 2    cartao_credito                       1 -15.83 -47.86
# 3            boleto                       1 -30.17 -53.50
# 4            boleto                       1 -18.10 -44.38

# %% [markdown]
# # Preparando Dados

# %%
#Nomeando as lojas
loja1['loja'] = 'Loja 1'
loja2['loja'] = 'Loja 2'
loja3['loja'] = 'Loja 3'
loja4['loja'] = 'Loja 4'

# %%
# Concatena todas as lojas
df = pd.concat([loja1, loja2, loja3, loja4], ignore_index=True)

# %%
# Converte coluna de data para datetime
df['Data da Compra'] = pd.to_datetime(df['Data da Compra'], dayfirst=True, errors='coerce')

# %%
# Definição de colunas de interesse
valor_col   = 'Preço'
frete_col   = 'Frete'
cat_col     = 'Categoria do Produto'
produto_col = 'Produto'
aval_col    = 'Avaliação da compra'
data_col    = 'Data da Compra'

# %% [markdown]
# #1. Análise do faturamento

# %% [markdown]
# ## 1.1 Faturamento total por loja (gráfico de barras)

# %%
fat_loja = df.groupby('loja')[valor_col].sum().sort_values(ascending=False)
plt.figure()
fat_loja.plot(kind='bar')
plt.title('Faturamento Total por Loja')
plt.ylabel('R$ faturados')
plt.xlabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 1.2 Faturamento mensal agregado

# %%
df['mes'] = df[data_col].dt.to_period('M').dt.to_timestamp()
fat_mensal = df.groupby('mes')[valor_col].sum().sort_index()
plt.figure()
plt.plot(fat_mensal.index, fat_mensal.values, marker='o')
plt.title('Faturamento Mensal Total (todas as lojas)')
plt.xlabel('Mês')
plt.ylabel('R$ faturados')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Vendas por Categoria

# %%
vendas_cat = df[cat_col].value_counts()
plt.figure()
vendas_cat.plot(kind='pie', autopct='%1.1f%%')
plt.title('Participação de Vendas por Categoria')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
aval_loja = df.groupby('loja')[aval_col].mean().sort_values()
plt.figure()
aval_loja.plot(kind='barh')
plt.title('Avaliação Média por Loja')
plt.xlabel('Nota média')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
contagem_prod = df[produto_col].value_counts()
top5 = contagem_prod.head(5)
bot5 = contagem_prod.tail(5)

plt.figure()
top5.plot(kind='bar')
plt.title('Top 5 Produtos Mais Vendidos')
plt.ylabel('Número de vendas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure()
bot5.plot(kind='bar')
plt.title('5 Produtos Menos Vendidos')
plt.ylabel('Número de vendas')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio = df.groupby('loja')[frete_col].mean().sort_values(ascending=False)

plt.figure()
frete_medio.plot(kind='bar')
plt.title('Frete Médio por Loja')
plt.ylabel('R$ Frete Médio')
plt.xlabel('')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
